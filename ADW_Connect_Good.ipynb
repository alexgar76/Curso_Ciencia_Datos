# %% [markdown]
# <a href="https://colab.research.google.com/github/alexgar76/Curso_Ciencia_Datos/blob/main/ADW_Connect_Good.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cx_Oracle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.9/363.9 kB 6.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for cx_Oracle: filename=cx_oracle-8.3.0-cp312-cp312-linux_x86_64.whl size=854024 sha256=adb8f2768299b3ea92f430269d2f767b1524036cb3af3e2f6977438e5bbe4c26
#   Stored in directory: /root/.cache/pip/wheels/c2/36/74/ca03900db8246dfd872cb23f51299a034ff843b7c15e87b5dd
# Successfully built cx_Oracle
# ...

# %%
import os
os.environ['TNS_ADMIN'] = '/usr/lib/oracle/19.3/client64/lib/network/admin' # Replace with your wallet directory

# %%
import oracledb

try:
        connection = oracledb.connect("admin", "Al3xG@r051976", "(description= (retry_count=20)(retry_delay=3)(address=(protocol=tcps)(port=1522)(host=adb.us-phoenix-1.oraclecloud.com))(connect_data=(service_name=g761f5f43f679f1_dbpython_high.adb.oraclecloud.com)))")
        cursor = connection.cursor()
        print("Successfully connected to Autonomous Database!")

        # Example: Execute a query
        cursor.execute("SELECT SYSDATE FROM DUAL")
        result = cursor.fetchone()
        print(f"Current date from ADB: {result[0]}")

except oracledb.Error as e:
        print(f"Error connecting to Autonomous Database: {e}")

finally:
        if 'connection' in locals() and connection:
            connection.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2649313137.py in <cell line: 0>()
#       2
#       3 try:
# ----> 4         connection = oracledb.connect("admin", "Al3xG@r051976", "(description= (retry_count=20)(retry_delay=3)(address=(protocol=tcps)(port=1522)(host=adb.us-phoenix-1.oraclecloud.com))(connect_data=(service_name=g761f5f43f679f1_dbpython_high.adb.oraclecloud.com)))")
#       5         cursor = connection.cursor()
#       6         print("Successfully connected to Autonomous Database!")
#
# TypeError: connect() takes from 0 to 1 positional arguments but 3 were given

# %%
# !pip install oracledb

# %%
! ls -l oracle-instantclient*-sqlplus-*.rpm   || wget https://yum.oracle.com/repo/OracleLinux/OL7/oracle/instantclient/x86_64/getPackage/oracle-instantclient19.3-sqlplus-19.3.0.0.0-1.x86_64.rpm

# %%
from google.colab import files #Upload Wallet
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0afa1413-3230-4963-87b7-a1675bcaf060" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0afa1413-3230-4963-87b7-a1675bcaf060">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -o -d /usr/lib/oracle/19.3/client64/lib/network/admin Wallet_*.zip
# Out:
# Archive:  Wallet_DBPython.zip
#   inflating: /usr/lib/oracle/19.3/client64/lib/network/admin/ewallet.pem
#   inflating: /usr/lib/oracle/19.3/client64/lib/network/admin/README
#   inflating: /usr/lib/oracle/19.3/client64/lib/network/admin/cwallet.sso
#   inflating: /usr/lib/oracle/19.3/client64/lib/network/admin/tnsnames.ora
#   inflating: /usr/lib/oracle/19.3/client64/lib/network/admin/truststore.jks
#   inflating: /usr/lib/oracle/19.3/client64/lib/network/admin/ojdbc.properties
#   inflating: /usr/lib/oracle/19.3/client64/lib/network/admin/sqlnet.ora
#   inflating: /usr/lib/oracle/19.3/client64/lib/network/admin/ewallet.p12
#   inflating: /usr/lib/oracle/19.3/client64/lib/network/admin/keystore.jks

# %%
from getpass import getpass
password = getpass('Enter the user password:')
# Out:
# Enter the user password:··········

# %%
# !sqlplus -L admin/$password@dbpython_medium <<<'show user'
# Out:
# /bin/bash: line 1: sqlplus: command not found

# %%
import os
import cx_Oracle as cx
import pandas as pd
import sqlalchemy as db
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, String, Integer
from sqlalchemy.orm import sessionmaker
import warnings
warnings.filterwarnings('ignore')
con = cx.connect(user="ADMIN", password=password, dsn="dbpython_medium")
query = 'SELECT * from  song'
data_train_2 = pd.read_sql(query, con=con) #Load data into DF
data_train_2.head()
# Out:
#                ARTIST                    SONG  DURATION_MS EXPLICIT  YEAR  \
# 0              Avicii  SOS (feat. Aloe Blacc)       157202    FALSE  2019
# 1  Tyler, The Creator               EARFQUAKE       190066     TRUE  2019
# 2            Ashley O               On A Roll       154447    FALSE  2019
# 3        Dominic Fike                3 Nights       177666    FALSE  2018
# 4              Sigala           Wish You Well       205653    FALSE  2019
#
#    POPULARITY  DANCEABILITY  ENERGY  KEY  LOUDNESS  MODO  SPEECHINESS  \
# 0          71         0.802   0.645    5    -6.181     0       0.0715
# 1          80         0.554   0.498    9    -8.866     1       0.0685
# 2          57         0.736   0.810    5    -6.354     1       0.0906
# 3          78         0.815   0.518    7    -6.594     0       0.0897
# 4          64         0.669   0.895    5    -3.787     0       0.0575
#
#    ACOUSTICNESS  INSTRUMENTALNESS  LIVENESS  VALENCE    TEMPO  \
# ...

# %%
# !pip install cx_Oracle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.9/363.9 kB 6.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for cx_Oracle: filename=cx_oracle-8.3.0-cp312-cp312-linux_x86_64.whl size=854023 sha256=de91b7f44b08fd77be19f15df7668b5fc2581b9211d301a66be8ad382c5c9c24
#   Stored in directory: /root/.cache/pip/wheels/c2/36/74/ca03900db8246dfd872cb23f51299a034ff843b7c15e87b5dd
# Successfully built cx_Oracle
# ...
