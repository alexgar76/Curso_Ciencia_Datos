# %% [markdown]
# <a href="https://colab.research.google.com/github/alexgar76/Curso_Ciencia_Datos/blob/main/pd_Datafra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ejm Dataframe desde un archivos csv
import pandas as pd
df = pd.read_csv ("/content/drive/MyDrive/archivos_colab/songs.csv",sep=',' ,decimal='.')
print(df.head)

# %%
#exporta archivo csv a otro
import pandas as pd
#with open("/content/drive/MyDrive/archivos_colab/songs.csv") as f:*/
df = pd.read_csv ("/content/drive/MyDrive/archivos_colab/songs.csv",sep=',' ,decimal='.')
df.to_csv("/content/drive/MyDrive/archivos_colab/songs1.csv")
print(df)

# %% [markdown]
# Atributos de Dataframe

# %%
import pandas as pd
df =pd.read_csv ("/content/drive/MyDrive/archivos_colab/songs.csv",sep=',' ,decimal='.')
# devuelve el informacion ((número de filas, número de columnas, índices,
# tipo de las columnas y memoria usado)
df.info()

# %%
import pandas as pd
df =pd.read_csv ("/content/drive/MyDrive/archivos_colab/songs.csv",sep=',' ,decimal='.')
# Devuelve una tupla con el número de filas y columnas del DataFrame
df.shape
# Out:
# (2000, 18)

# %%
import pandas as pd
df =pd.read_csv ("/content/drive/MyDrive/archivos_colab/songs.csv",sep=',' ,decimal='.')
# Devuelve el número de elementos del DataFrame
df.size
# Out:
# 36000

# %%
import pandas as pd
df =pd.read_csv ("/content/drive/MyDrive/archivos_colab/songs.csv",sep=',' ,decimal='.')
#Devuelve una lista con los nombres de las columnas del DataFrame
df.columns
# Out:
# Index(['artist', 'song', 'duration_ms', 'explicit', 'year', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'genre'],
#       dtype='object')

# %%
import pandas as pd
df =pd.read_csv ("/content/drive/MyDrive/archivos_colab/songs.csv",sep=',' ,decimal='.')
#Devuelve una lista con los nombres de las filas del DataFrame
df.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
import pandas as pd
df =pd.read_csv ("/content/drive/MyDrive/archivos_colab/songs.csv",sep=',' ,decimal='.')
#Devuelve una serie con los tipos de datos de las columnas del DataFrame
df.dtypes
# Out:
# artist               object
# song                 object
# duration_ms           int64
# explicit               bool
# year                  int64
# popularity            int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# genre                object
# dtype: object

# %%
import pandas as pd
df =pd.read_csv ("/content/drive/MyDrive/archivos_colab/songs.csv",sep=',' ,decimal='.')
#Devuelve las n primeras filas del DataFrame
df.head(10)
# Out:
#             artist                    song  duration_ms  explicit  year  \
# 0   Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1        blink-182    All The Small Things       167066     False  1999
# 2       Faith Hill                 Breathe       250546     False  1999
# 3         Bon Jovi            It's My Life       224493     False  2000
# 4           *NSYNC             Bye Bye Bye       200560     False  2000
# 5            Sisqo              Thong Song       253733      True  1999
# 6           Eminem     The Real Slim Shady       284200      True  2000
# 7  Robbie Williams                 Rock DJ       258560     False  2000
# 8  Destiny's Child             Say My Name       271333     False  1999
# 9            Modjo  Lady - Hear Me Tonight       307153     False  2001
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# ...

# %%
import pandas as pd
df =pd.read_csv ("/content/drive/MyDrive/archivos_colab/songs.csv",sep=',' ,decimal='.')
#Devuelve las n últimas filas del DataFrame
df.tail()
# Out:
#               artist                                    song  duration_ms  \
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# 1995     False  2019          79         0.842   0.734    1    -5.065     0
# 1996     False  2019          78         0.552   0.702    9    -5.707     1
# 1997     False  2019          69         0.847   0.678    9    -8.635     1
# 1998     False  2019          75         0.741   0.520    8    -7.513     1
# 1999     False  2019          85         0.695   0.762    0    -3.497     1
#
# ...

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesterol.csv')
print(df)
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %%
#renombrar columnas de dataframe y el indice de la fila
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesterol.csv')
print(df.rename(columns={'nombre':'Nombre & Apellidos','altura':'Estatura'}, index={0:1001,1:1002,3:1003,13:133}))
# Out:
#                    Nombre & Apellidos  edad sexo   peso  Estatura  colesterol
# 1001     José Luis Martínez Izquierdo    18    H   85.0      1.79       182.0
# 1002                   Rosa Díaz Díaz    32    M   65.0      1.73       232.0
# 2               Javier García Sánchez    24    H    NaN      1.81       191.0
# 1003              Carmen López Pinzón    35    M   65.0      1.70       200.0
# 4                Marisa López Collado    46    M   51.0      1.58       148.0
# 5                   Antonio Ruiz Cruz    68    H   66.0      1.74       249.0
# 6             Antonio Fernández Ocaña    51    H   62.0      1.72       276.0
# 7               Pilar Martín González    22    M   60.0      1.66         NaN
# 8                Pedro Gálvez Tenorio    35    H   90.0      1.94       241.0
# 9             Santiago Reillo Manzano    46    H   75.0      1.85       280.0
# 10              Macarena Álvarez Luna    53    M   55.0      1.62       262.0
# ...

# %%
#cambiar indice de Dataframe
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesterol.csv')
print(df.set_index('nombre',verify_integrity=True).head())
# Out:
#                               edad sexo  peso  altura  colesterol
# nombre
# José Luis Martínez Izquierdo    18    H  85.0    1.79       182.0
# Rosa Díaz Díaz                  32    M  65.0    1.73       232.0
# Javier García Sánchez           24    H   NaN    1.81       191.0
# Carmen López Pinzón             35    M  65.0    1.70       200.0
# Marisa López Collado            46    M  51.0    1.58       148.0

# %%
import pandas as pd
df =pd.read_csv ("/content/drive/MyDrive/archivos_colab/songs.csv",sep=',' ,decimal='.')
print(df)
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...
